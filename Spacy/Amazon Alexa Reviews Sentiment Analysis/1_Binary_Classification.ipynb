# %% [markdown]
# # Libs

# %%
# !pip install -U spacy
# !python -m spacy validate
# Out:
# ...
# ✔ Loaded compatibility table
#
# ================= Installed pipeline packages (spaCy v3.2.0) =================
# ℹ spaCy installation: /usr/local/lib/python3.7/dist-packages/spacy
#
# No pipeline packages found in your current environment.

# %%
# !python -m spacy download en_core_web_lg
# Out:
# ...
#      |████████████████████████████████| 777.4 MB 6.4 kB/s
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# !pip install spacy-transformers

# %%
import numpy as np
import pandas as pd

import spacy
import spacy_transformers
from spacy.tokens import DocBin

nlp=spacy.load("en_core_web_lg") # version 3.0 does not work i should download version 3.2 # nlp=spacy.load("en_core_web_lg") ##nlp=spacy.load("en_core_web_trf")
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %% [markdown]
# # Data

# %%
df = pd.read_excel(r'/content/amazon_alexa.xlsx')
df=df[['verified_reviews' , 'feedback']]
print(type(df))
train = df.sample(frac = 0.8, random_state = 25)
test = df.drop(train.index)
print(train.shape, test.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (2520, 2) (630, 2)

# %%
records = train.to_records(index=False)
train = list(records)
print(train[0])

records_ = test.to_records(index=False)
test = list(records_)
print(test[0])
# Out:
# ('What can I say. Well, I’m a  paranoid IT person of 30 years but got hooked on the idea of cloud based home control. So yes I love my echo stuff but, I did create a isolated VLAN on my home network to run the devices including the cheap ones that require you to sign up on some questionable website and download their app. Be carful with these people!  Entering your Wi-Fi password on a site that’s not vetted and your location when the app askes is not a good thing. Try to stay with devices that  work directly with the Alexa hub with no third-party app, Amazon has more control of these types of devices and how the  sensitive information is handled.', 1)
# ('I sent it to my 85 year old Dad, and he talks to it constantly.', 1)

# %% [markdown]
# # Processing

# %%
def document(data):

    text = []
    for doc, label in nlp.pipe(data, as_tuples = True):
        if (label==1):
            print("yes")
            doc.cats['positive'] = 1
            doc.cats['negative'] = 0
            doc.cats['neutral']  = 0
        elif(label==0):
            print("yess")
            doc.cats['positive'] = 0
            doc.cats['negative'] = 1
            doc.cats['neutral']  = 0
    text.append(doc)

    return(text)

print(train[0][1])
a=document(train[0:2])
print(a)
a[0].cats
# Out:
# 1
# yes
# yes
# [awesome.understands my kids]
# {'negative': 0, 'neutral': 0, 'positive': 1}

# %%
# %%time

train_docs = document(train)
print(train_docs[0].cats)

#Creating binary document using DocBin function in spaCy
doc_bin = DocBin(docs = train_docs)

#Saving the binary document as train.spacy
doc_bin.to_disk("train.spacy")
# Out:
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yess
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yess
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yess
# yess
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yes
# yes
# yes
# ...

# %%
# %%time

test_docs = document(test)
doc_bin = DocBin(docs = test_docs)
doc_bin.to_disk("dev.spacy")
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yess
# yess
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yes
# yess
# yess
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yess
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ...

# %% [markdown]
# # Modeling

# %%
# https://spacy.io/usage/training#quickstart
# !python -m spacy init fill-config ./base_config1.cfg ./config.cfg
# I chnaged the directory since it gives me this error Error: Invalid value for 'BASE_PATH': File 'r'C:/Users/mayadi/Documents/Work/PWM/Code/New' does not exist.
# !python -m spacy init fill-config /content/base_config.cfg ./config.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# %%time
# !python -m spacy train /content/config.cfg --output training/ --paths.train train.spacy --paths.dev dev.spacy --gpu-id -1
# Out:
# ✔ Created output directory: training
# ℹ Saving to output directory: training
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# [2021-11-27 20:32:37,847] [INFO] Set up nlp object from config
# [2021-11-27 20:32:37,861] [INFO] Pipeline: ['textcat']
# [2021-11-27 20:32:37,866] [INFO] Created vocabulary
# [2021-11-27 20:32:37,869] [INFO] Finished initializing nlp object
# [2021-11-27 20:32:37,898] [INFO] Initialized pipeline components: ['textcat']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['textcat']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TEXTCAT  CATS_SCORE  SCORE
# ---  ------  ------------  ----------  ------
#   0       0          0.67        0.00    0.00
# 200     200         17.95       33.33    0.33
# 400     400          0.84       33.33    0.33
# 600     600          0.36       33.33    0.33
# 800     800          0.21       33.33    0.33
# ...

# %%
nlp= spacy.load(r'/content/training/model-best')

# %%
print(train[7])
print(train[7][0])
# Out:
# ('Easy setup, works flawlessly!', 1)
# Easy setup, works flawlessly!

# %%
demo = nlp(train[7][0])
print('Result: ', 1 if demo.cats['positive'] > demo.cats['negative'] else 0)
#demo.cats
# Out:
# Result:  1
